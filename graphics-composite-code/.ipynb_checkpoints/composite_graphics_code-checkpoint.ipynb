# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nrclex import NRCLex
import emoji
import regex

import pandas as pd
import numpy as np
import collections, functools, operator
from collections import Counter
import matplotlib.pyplot as plt

# %%
df = pd.read_json("C:/Users/zhuang/Documents/GitHub/twitter-hook-graphics/data/lebron_james_tweets.json")

# %%
df
# Out:
#                    created_at                   id               id_str  \
# 0   2022-04-28 09:10:34+00:00  1519604977341149185  1519604977341149184
# 1   2022-04-28 04:33:23+00:00  1519535223175729152  1519535223175729152
# 2   2022-04-28 04:32:18+00:00  1519534951531573248  1519534951531573248
# 3   2022-04-27 02:21:12+00:00  1519139570247368704  1519139570247368704
# 4   2022-04-27 01:12:59+00:00  1519122403598557185  1519122403598557184
# ..                        ...                  ...                  ...
# 395 2021-08-30 03:38:59+00:00  1432186058821672963  1432186058821672960
# 396 2021-08-29 14:10:56+00:00  1431982704380157955  1431982704380157952
# 397 2021-08-28 01:36:43+00:00  1431430510727680009  1431430510727680000
# 398 2021-08-28 01:36:40+00:00  1431430499528941574  1431430499528941568
# 399 2021-08-28 00:10:41+00:00  1431408861374607362  1431408861374607360
#
#                                              full_text  truncated  \
# 0                    🫡!!!!! 🙏🏾 https://t.co/0Z1aApRGCM      False
# 1    We just working! That’s all it is. #JamesGang👑...      False
# 2                                 Game 🏀 @Garydwayne!!      False
# 3                                         JA!!!!!!! 💪🏾      False
# 4                🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥 https://t.co/7VmK7RSOzu      False
# ..                                                 ...        ...
# 395  CLEVELAND IS JUMPING!! Should have flew back t...      False
# 396    @BJwhite Yessir!! Tune Squad for the win! 🙏🏾❤️👑      False
# 397  RT @uninterrupted: It's always on to the next ...      False
# 398  RT @uninterrupted: "Like for what? I can't bre...      False
# 399  Man helluva pitch and catch from @PatrickMahom...      False
#
#     display_text_range                                           entities  \
# 0               [0, 9]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1              [0, 46]  {'hashtags': [{'text': 'JamesGang', 'indices':...
# 2              [0, 20]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 12]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4              [0, 13]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 395            [0, 57]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 396            [9, 47]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 397           [0, 140]  {'hashtags': [{'text': 'TheShop', 'indices': [...
# 398           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 399            [0, 64]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="http://twitter.com/download/iphone" r...                    NaN
# 1    <a href="http://twitter.com/download/iphone" r...                    NaN
# 2    <a href="http://twitter.com/download/iphone" r...                    NaN
# 3    <a href="http://twitter.com/download/iphone" r...                    NaN
# 4    <a href="http://twitter.com/download/iphone" r...                    NaN
# ..                                                 ...                    ...
# 395  <a href="http://twitter.com/download/iphone" r...                    NaN
# 396  <a href="http://twitter.com/download/iphone" r...           1.431721e+18
# 397  <a href="http://twitter.com/download/iphone" r...                    NaN
# 398  <a href="http://twitter.com/download/iphone" r...                    NaN
# 399  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#      in_reply_to_status_id_str  ...  \
# 0                          NaN  ...
# 1                          NaN  ...
# 2                          NaN  ...
# 3                          NaN  ...
# 4                          NaN  ...
# ..                         ...  ...
# 395                        NaN  ...
# 396               1.431721e+18  ...
# 397                        NaN  ...
# 398                        NaN  ...
# 399                        NaN  ...
#
#                                quoted_status_permalink  \
# 0    {'url': 'https://t.co/0Z1aApRGCM', 'expanded':...
# 1    {'url': 'https://t.co/lyL8OMdHZA', 'expanded':...
# 2                                                  NaN
# 3                                                  NaN
# 4    {'url': 'https://t.co/7VmK7RSOzu', 'expanded':...
# ..                                                 ...
# 395                                                NaN
# 396                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
#
#                                          quoted_status retweet_count  \
# 0    {'created_at': 'Thu Apr 28 02:05:08 +0000 2022...           843
# 1    {'created_at': 'Wed Apr 27 22:56:50 +0000 2022...           967
# 2                                                  NaN          1642
# 3                                                  NaN          8864
# 4    {'created_at': 'Tue Apr 26 12:11:28 +0000 2022...           585
# ..                                                 ...           ...
# 395                                                NaN          2650
# 396                                                NaN            50
# 397                                                NaN           165
# 398                                                NaN           154
# 399                                                NaN           477
#
#     favorite_count  favorited  retweeted  possibly_sensitive  lang  \
# 0            13300      False      False                 0.0   und
# 1            19003      False      False                 0.0    en
# 2            29043      False      False                 NaN    en
# 3           132821      False      False                 NaN   und
# 4             8154      False      False                 0.0   und
# ..             ...        ...        ...                 ...   ...
# 395          67052      False      False                 NaN    en
# 396           3628      False      False                 NaN    en
# 397              0      False      False                 0.0    en
# 398              0      False      False                 NaN    en
# 399          10235      False      False                 NaN    en
#
#                                      extended_entities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 395                                                NaN
# 396                                                NaN
# 397  {'media': [{'id': 1431356524111224836, 'id_str...
# 398                                                NaN
# 399                                                NaN
#
#                                       retweeted_status
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 395                                                NaN
# 396                                                NaN
# 397  {'created_at': 'Sat Aug 28 01:16:00 +0000 2021...
# 398  {'created_at': 'Sat Aug 28 01:25:00 +0000 2021...
# 399                                                NaN
#
# [400 rows x 31 columns]

# %%
def analyze_sentiment(text):
    vader_sent_dicts = []

    analyzer = SentimentIntensityAnalyzer()
    for sentence in list(text):
        vs = analyzer.polarity_scores(sentence)
        vader_sent_dicts.append(vs)
    
    sent_class = []

    for i in vader_sent_dicts:
        if i["compound"] >= 0.05:
            sent_class.append("positive")
        elif i["compound"] <= -0.05:
            sent_class.append("negative")
        else:
            sent_class.append("neutral")
            
    return Counter(sent_class)

# %%
def get_nrc_values(text):
    nrc_dicts = []

    for i in list(text):

        text_object = NRCLex(i)
        
        nrc_dicts.append(text_object.raw_emotion_scores)
        
    result = dict(functools.reduce(operator.add,map(collections.Counter, nrc_dicts)))
        
    del result["positive"]
    del result["negative"]
        
    return result

# %%
def make_pie_chart(d, typeof="sentiment"):
    
    if typeof == "sentiment":
        labels = ['neutral', 'positive', 'negative']
        sizes = [d['neutral'], d["positive"], d["negative"]]
        title = "Your tweets by emotional category"
        
        
    elif typeof == "nrc":
        labels = ['nrc_trust', 'nrc_fear', 'nrc_anticipation',
       'nrc_surprise', 'nrc_disgust', 'nrc_sadness',
       'nrc_anger', 'nrc_joy']
        sizes = [d[i] for i in labels]
        title = "Words in your tweets by emotional subcategory"
        
    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, labels=labels)
    ax1.axis('equal')  
    plt.title(title)
    plt.show()

# %%
def extract_emojis(s):
    return [c for c in s if c in emoji.UNICODE_EMOJI['en']]

# %%
extract_emojis(df.full_text[0])
# Out:
# ['\U0001fae1', '🙏', '🏾']
